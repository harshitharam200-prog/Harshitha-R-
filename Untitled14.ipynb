# %%
i=1
while i<=10:
  if i==6:
    i+=1
    continue
    print(i)
    i+=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4254630956.py in <cell line: 0>()
#       1 i=1
# ----> 2 while i<=10:
#       3   if i==6:
#       4     i+=1
#       5     continue
#
# KeyboardInterrupt:
