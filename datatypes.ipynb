# %%
list1=[1,2,3,4,'hi']
print(list1)
# Out:
# <class 'list'>

# %%
ph=float(input("enter soil ph value"))
if (ph<5.5):
  print( "acidic soil")
elif(ph<=7.5):
  print("neutral soil")
elif(ph<=8.5):
  print("alkaline soil")
else:
  print("highly alkaline soil")
# Out:
#   File "/tmp/ipython-input-574353836.py", line 8
#     else("highly alkaline soil"):
#         ^
# SyntaxError: expected ':'

# %%
x=[10,11,13,14]
if 12 not in x:
  print(" 12 is absent in x")
if 11 in x:
  print(" 11 is present in x")
print("end")

# %%
x=[10,11,13,14]
if 12 not in x:
  print("")

# %%
crops= ["rice","wheat","maize"]
 print (" crops grown in the field:")
 for i in crops:
  print(i)

# %%
crops.appent ("sugarcane")
 print("crops")

# %%
print("number of crops grown:",len(crops))

# %%
if "maize" in crops:
  print(" maize is present in list of crops")
if onion in crops:
  print("onion present in list of crops")
else:
  print(" onion is not present in list of crops")

# %%
crops.remove(1)
 print("crops")

# %%
crops.index("maize")
print("maize is at index:",index_maize)
print(crops.index("maize"))
