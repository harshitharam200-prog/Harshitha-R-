# %%
cost =[20,23,45,67]
average
print("average cost:",average_cost)
for i in range (len(cost)):
  if cost[i]>average_cost:
    count=count+1
    print(count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-605278606.py in <cell line: 0>()
#       1 cost =[20,23,45,67]
# ----> 2 print("average cost:",average_cost)
#       3 for i in range (len(cost)):
#       4   if cost[i]>average_cost:
#       5     count=count+1
#
# NameError: name 'average_cost' is not defined
