# %%
import pandas as pd
import numpy as np
#create data with missing values
data=pd.DataFrame({
    'plot':['A','B','C','D','E'],
    'Yield_kg':[2500,np.nan,2800,np.nan,2600], #nan means not a number
    'rainfall':[150,200,np.nan,180,120],
    'temperature':[28,30,29,np.nan,27]
    })
print("===data with missing values===")
print(data)
# Out:
# ===data with missing values===
#   plot  Yield_kg  rainfall  temperature
# 0    A    2500.0     150.0         28.0
# 1    B       NaN     200.0         30.0
# 2    C    2800.0       NaN         29.0
# 3    D       NaN     180.0          NaN
# 4    E    2600.0     120.0         27.0

# %%
#===detecting missing data===
print("\n===detecting missing data===")
print("is null?")
print(data.isnull())
print(f"\n{data.isnull().sum()}")
# Out:
# ===detecting missing data===
# is null?
#     plot  Yield_kg  rainfall  temperature
# 0  False     False     False        False
# 1  False      True     False        False
# 2  False     False      True        False
# 3  False      True     False         True
# 4  False     False     False        False
#
# plot           0
# Yield_kg       2
# rainfall       1
# temperature    1
# dtype: int64

# %%
#fillna method to fill not a number
#fill missing values
print("\n===filling strategies===")
#fill with mean
data_mean=data.copy()
print(data_mean["Yield_kg"])
data_mean["Yield_kg"]=data_mean["Yield_kg"].fillna(data_mean["Yield_kg"].mean())
print("\n","fill with mean:")
print(data_mean["Yield_kg"])
# Out:
# ===filling strategies===
# 0    2500.0
# 1       NaN
# 2    2800.0
# 3       NaN
# 4    2600.0
# Name: Yield_kg, dtype: float64
#
#  fill with mean:
# 0    2500.000000
# 1    2633.333333
# 2    2800.000000
# 3    2633.333333
# 4    2600.000000
# Name: Yield_kg, dtype: float64

# %%
#fill with median
data_median = data.copy()
print(data_median["rainfall"])
data_median["rainfall"]=data_median["rainfall"].fillna(data_median["rainfall"].median())
print("\n","fill with median:")
print(data_median)
# Out:
# 0    150.0
# 1    200.0
# 2      NaN
# 3    180.0
# 4    120.0
# Name: rainfall, dtype: float64
#
#  fill with median:
#   plot  Yield_kg  rainfall  temperature
# 0    A    2500.0     150.0         28.0
# 1    B       NaN     200.0         30.0
# 2    C    2800.0     165.0         29.0
# 3    D       NaN     180.0          NaN
# 4    E    2600.0     120.0         27.0

# %%
#forward fill(use previous value)
data_ffill=data.copy()
print(data_ffill)
data_ffill=data_ffill.fillna(method="ffill")
print("\nForwardFill:")
print(data_ffill)
# Out:
#   plot  Yield_kg  rainfall  temperature
# 0    A    2500.0     150.0         28.0
# 1    B       NaN     200.0         30.0
# 2    C    2800.0       NaN         29.0
# 3    D       NaN     180.0          NaN
# 4    E    2600.0     120.0         27.0
#
# ForwardFill:
#   plot  Yield_kg  rainfall  temperature
# 0    A    2500.0     150.0         28.0
# 1    B    2500.0     200.0         30.0
# 2    C    2800.0     200.0         29.0
# 3    D    2800.0     180.0         29.0
# 4    E    2600.0     120.0         27.0
# /tmp/ipython-input-1847619478.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_ffill=data_ffill.fillna(method="ffill")

# %%
#droping missing data
print("\nDropping rows:")
data_dropped=data.dropna()
print(data_dropped)
print(f"original rows:{len(data)},after drop :{len(data_dropped)}")
# Out:
# Dropping rows:
#   plot  Yield_kg  rainfall  temperature
# 0    A    2500.0     150.0         28.0
# 4    E    2600.0     120.0         27.0
# original rows:5,after drop :2
