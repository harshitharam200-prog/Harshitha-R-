# %%
T= ("harshitha","ram",3.4,8.9)
print("T",t)
# Out:
# T ('harsh', 'ram', 5.6, 6)

# %%
print("number of elements in T:",len(T))
# Out:
# number of elements in T: 4

# %%
print("type of object",type(t))
# Out:
# type of object <class 'tuple'>

# %%
i=0
print("")
while i<len(T):
    print(T[i])
    i+=1
# Out:
# harshitha
# ram
# 3.4
# 8.9

# %%
print("")
for i in range (len(T)):
  print(T[i])
# Out:
# harshitha
# ram
# 3.4
# 8.9

# %%
t=("coffee","matcha","latte","mocha","espresso")
print("t",t)
# Out:
# t ('coffee', 'matcha', 'latte', 'mocha', 'espresso')

# %%
print ("t[1]",t[1])
print("t[-4]",t[-4])
print(t[-5])
print(t[3])
print(t[0])
print(t[-3:-1])
print(t[:-4])
print(t[::1])
# Out:
# t[1] matcha
# t[-4] matcha
# coffee
# mocha
# coffee
# ('latte', 'mocha')
# ('coffee',)
# ('coffee', 'matcha', 'latte', 'mocha', 'espresso')

# %%
t=("coffee","matcha","latte","mocha","espresso")
print(t[::2])
print(t[::3])
print(t[::-1])
print(t[::-2])
# Out:
# ('coffee', 'latte', 'espresso')
# ('coffee', 'mocha')
# ('espresso', 'mocha', 'latte', 'matcha', 'coffee')
# ('espresso', 'latte', 'coffee')

# %%
t[::2]
t[::-1]
# Out:
# ('espresso', 'mocha', 'latte', 'matcha', 'coffee')

# %%
t[::-1]
# Out:
# ('espresso', 'mocha', 'latte', 'matcha', 'coffee')

# %%
t[4]="tea"
print('t',t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-132435928.py in <cell line: 0>()
# ----> 1 t[4]="tea"
#       2 print('t',t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.append("tea")
print	("t",t)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1202343134.py in <cell line: 0>()
# ----> 1 t.append("tea")
#       2 print   ("t",t)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t.add("tea")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1234459993.py in <cell line: 0>()
# ----> 1 t.add("tea")
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
t.insert("tea")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-290465461.py in <cell line: 0>()
# ----> 1 t.insert("tea")
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
del t["mocha"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3413494374.py in <cell line: 0>()
# ----> 1 del t["mocha"]
#
# TypeError: 'tuple' object does not support item deletion

# %%
t.extend("tea")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1344200656.py in <cell line: 0>()
# ----> 1 t.extend("tea")
#
# AttributeError: 'tuple' object has no attribute 'extend'

# %%
t=("coffee","matcha","latte","mocha","espresso")
print("beverages:",t)
t1=list(t)
t1.append("capuccino")
t=tuple(t1)
print("")
print("updated beverages:",t)
# Out:
# beverages ('coffee', 'matcha', 'latte', 'mocha', 'espresso')
#
# updated beverages: ('coffee', 'matcha', 'latte', 'mocha', 'espresso', 'capuccino')

# %%
t=("coffee","matcha","latte","mocha","espresso")
print("beverages:",t)
t1=list(t)
t1.insert(2,"tea")
t1.insert(4,"macchiato")

t=tuple(t1)
print("")
print("updated beverages:",t)
# Out:
# beverages: ('coffee', 'matcha', 'latte', 'mocha', 'espresso')
#
# updated beverages: ('coffee', 'matcha', 'tea', 'latte', 'macchiato', 'mocha', 'espresso')

# %%
del t1[1]
print("updated beverages after deletion:",t1)
# Out:
# updated beverages after deletion: ['coffee', 'macchiato', 'mocha', 'espresso']

# %%
print(type(t1))
# Out:
# <class 'list'>

# %%
print (type(t))
# Out:
# <class 'tuple'>

# %%
t=(2357480,5674356,890666,65432,5472699277)
print("sum",sum(t))
print("max",max(t))
print("min",min(t))
# Out:
# sum 5481687211
# max 5472699277
# min 65432

# %%
print("average",sum(t)/len(t))
# Out:
# average 1096337442.2

# %%
print("average",sum(t)//len (t))
# Out:
# average 1096337442

# %%
print("8 is  present in t:",8 in t)
# Out:
# 8 is  present in t: False

# %%
print("65432 is present  in t",65432 in t)
# Out:
# 65432 is present  in t True

# %%
t1=(23,456,678,567)
t2=(35,63,5,65)
print("t1:",t1)
print("t2:",t2)
t3=t1+t2
print ("t3:",t3)
t5=t3+t2
print("t5:",t5)
# Out:
# t1: (23, 456, 678, 567)
# t2: (35, 63, 5, 65)
# t3: (23, 456, 678, 567, 35, 63, 5, 65)
# t5: (23, 456, 678, 567, 35, 63, 5, 65, 35, 63, 5, 65)

# %%
t3=t1[1:3]+t2[1:2]
print("t3:",t3)
t4=t1[:-3]+t2[:-2]
print("t4:",t4)
# Out:
# t3: (456, 678, 63)
# t4: (23, 35, 63)

# %%
t=(23,456,678,567)
print(" index of 23 in t",t.index(23))
# Out:
#  index of 23 in t 0

# %%
t=(23,23,23,456,678,567)
print(" index of 34 in t",t.index(34))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3190789401.py in <cell line: 0>()
#       1 t=(23,456,678,567)
# ----> 2 print(" index of 34 in t",t.index(34))
#
# ValueError: tuple.index(x): x not in tuple

# %%
t=(23,23,23,456,678,567)
print(" t.count(3)",t.count(3))
# Out:
#  t.count(3) 0

# %%
t=(23,23,23,456,678,567)
print(" count of 23 is",t.count(23))
# Out:
#  count of 23 is 3

# %%
l1=[1,2,3,4,5,6]
print(id(l1))
l1.append(7)
print(id( l1))
# Out:
# 133690405799808
# 133690405799808

# %%
s1={12,3,45,66,454}
print(id(s1))
s1.add(567)
print(id(s1))
# Out:
# 133690408576032
# 133690408576032

# %%
a="gkvk"
print(a)
a1=a +" "+"university"
print(a1)
# Out:
# gkvk
# gkvk university

# %%
d={1:"one",2:"two",3:"three",4:"four"}
print(id(d))
d["c"]=3
print(id(d))
# Out:
# 133690408299456
# 133690408299456

# %%
a="gkvk"
print(id(a))
a1=a+"university"
print(id(a1))
# Out:
# 133690418617568
# 133690405813104

# %%
a="python"
print(id(a))
a1=a+"3"
print(id(a1))
print(a1)
# Out:
# 133691494251376
# 133690418617568
# python3

# %%
a="python"
a[0]="j"
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4002949357.py in <cell line: 0>()
#       1 a="python"
# ----> 2 a[0]="j"
#       3 print(a)
#
# TypeError: 'str' object does not support item assignment

# %%
x=10
y=x
print(id(x))
print(id(y))
x=x+20
print(id(x))
print(id(y))
# Out:
# 11654664
# 11654664
# 11655304
# 11654664
