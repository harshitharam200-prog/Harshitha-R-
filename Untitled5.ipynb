# %%
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
a="H"
print(type(a))
# Out:
# <class 'str'>

# %%
a=(1,101,2)
print(type(a))
# Out:
# <class 'tuple'>

# %%
a=[2,101,5]
print(type(a))
# Out:
# <class 'list'>

# %%
a=10.5
print(type(a))
# Out:
# <class 'float'>

# %%
a=2
b=5
print("value of a and b are", a,b)
# Out:
# value of a and b are 2 5

# %%
a=10
b=20
print ("value of a and b are {0} and {1}".format(a,b))
# Out:
# value of a and b are 10 and 20

# %%
print("I love {2},{1} and {0}".format("relatives","friends","family"))
# Out:
# I love family,friends and relatives

# %%
a=input("enter a number")
print(a)
print(type(a))
# Out:
# enter a number2
# 2
# <class 'str'>

# %%
a=int(input("enter a number"))
print(a)
print(type(a))
# Out:
# enter a number9
# 9
# <class 'int'>

# %%
a=int(input("enter a number"))
b= int(input("enter a number"))
c=a*b
print(a)
print(b)
print(c)
print(type(a))
print(type(b))
print(type(c))
# Out:
# enter a number2
# enter a number4
# 2
# 4
# 8
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
a=input("enter a number")
b=int(input("enter a number"))
print(a)
print(b+10)
print(type(a))
print(type(b))
# Out:
# enter a number  dishant
# enter a number18
#   dishant
# 28
# <class 'str'>
# <class 'int'>

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
c=a*b
print("the product of {} and {} is {}".format(a,b,c))
# Out:
# enter a number3
# enter a number4
# the product of 3 and 4 is 12
