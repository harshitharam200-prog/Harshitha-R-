# %%
if 10>5:
  print("10 is greater than 5")
# Out:
# 10 is greater than 5

# %%
if 5>2:
  print("5 is greater than 2 ")
# Out:
# 5 is greater than 2

# %%
if 4==4:
  print("4 is equal to 4")
# Out:
# 4 is equal to 4

# %%
if 5.5>=5:
  print("5.5 is greater than or equal to 5")
# Out:
# 5.5 is greater than or equal to 5

# %%
a=234
b=567
if a<b:
  print("a is less than b")
# Out:
# a is less than b

# %%
x=34
if x>18:

  print("you are eligible to vote")
else:
  print("you are not eligible to vote")
# Out:
# you are eligible to vote

# %%
x=45
if x>21:
  print("print you are eligible to marry")
# Out:
# print you are eligible to marry

# %%
x=17
if x>18:
  print("you are eligible to marry")
else:
   print("you are not eligible to marry")
# Out:
# you are not eligible to marry

# %%
a=99
b=234
if a<b:
  print("a is less than b")
else:
  print("a is greater than b")
# Out:
# a is less than b

# %%
x=67
if x>35:
  print("you are pass")
else:
  print("you are fail")
# Out:
# you are pass

# %%
x=8900
if x>10000:
  x=salary
  print("you are taxable")
else:
  print("you are not taxable")
# Out:
# you are not taxable

# %%
x=500
y=490
if x>y:
  print("x is greater than y")
else:
  print("y is greater than x")
# Out:
# x is greater than y

# %%
x=990
y=980
if x>y:
  print("x is greater than y")
  print("y is less than x")
else:
  print("y is greater than x")
  print("x is less than y")
# Out:
# x is greater than y
# y is less than x

# %%
x=45

if x>60:
  x=age
  print("you are senior citizen")
else:
  print("you are not senior citizen")
# Out:
# you are not senior citizen

# %%
age =x=11

if x<18:

  print("you are  under adolscence age")
else:
  print("you are not under adolscence age")
# Out:
# you are  under adolscence age

# %%
age =x=35
if x>21:
  print("you are eligible to attempt upsc" )
else:
    print("you are not eligible to attempt upsc")
# Out:
# you are eligible to attempt upsc

# %%
x =10
if x >1 :
   print("positive")
elif x==0:
    print("zero")
else:
   print("negative")
# Out:
# positive

# %%
x=-45
if x>1:
  print("positive")
elif x==0:
  print("zero")
else:
  print("negative")
# Out:
# negative

# %%
x=0
if x==0:
  print("zero")
elif x>0:
  print("positive")
else:
  print("negative")
# Out:
# zero

# %%
x=9.8
if x>9:
  print("grade a")
elif x>=7 and x<9:
  print("grade b")
elif x>=5 and x<7:
  print ("grade c")
 else:
    print("fail")
# Out:
# grade a

# %%
x=89
if x%2==0:
  print("even number")
else:
    print("odd number")
# Out:
# odd number
