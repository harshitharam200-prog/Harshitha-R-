# %%
fruit="banana"
letter=fruit[4]
print(letter)
# Out:
# n

# %%
n=3
w=fruit[n-1]
print(w)
# Out:
# n

# %%
print(fruit(2.5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-970355954.py in <cell line: 0>()
# ----> 1 print(fruit(2.5))
#
# TypeError: 'str' object is not callable

# %%
b=3
print(fruit[b])
# Out:
# a

# %%
print(len(fruit))
# Out:
# 6

# %%
s="hello world"
print(s[-5:-4])
# Out:
# w

# %%
s="hello world"
print(s[:2])
# Out:
# he

# %%
s="cold coffee"
print(s[8:])
# Out:
# fee

# %%
print(s[:])
# Out:
# cold coffee

# %%
print(s[-8:-1])
# Out:
# d coffe

# %%
print(s[-9:])
# Out:
# ld coffee

# %%
print(s[:-6])
s1=s[:-6]
print(len(s1))
# Out:
# cold
# 5

# %%
print(s[-9:-5])
# Out:
# ld c

# %%
str1="hello"
str2="world"
print(str1+str2)
print(str1+"                  "+str2)
# Out:
# helloworld
# hello                  world

# %%
b=str1+"there"
print(b)
# Out:
# hellothere

# %%
print(str1*3)
# Out:
# hellohellohello

# %%
print(str1+"3")
# Out:
# hello3

# %%
c=str1+ "-" +"there"
print(c)
# Out:
# hello-there

# %%
s="hello""welcome"
print(s)
# Out:
# hellowelcome

# %%
s=("helloo"
... "world")
print(s)
# Out:
# hellooworld

# %%
s="hello"\
   "world"
print(s)
# Out:
# helloworld

# %%
s="hello world"
print("number of l in hello world is",s.count('l'))
# Out:
# number of l in hello world is 3

# %%
s="hello world"
c = 0
for i in s:
  if(i=="l"):
    c=c+1
print(c)
# Out:
# 3

# %%
fruit=("banana")
print("n" in fruit)
print("m" in fruit)
print("nan" in fruit)
print("naan" in fruit)
# Out:
# True
# False
# True
# False

# %%
if "a" in fruit:
  print("found it!")
# Out:
# found it!

# %%
fruit="bananananana"
fruit.count("na")
# Out:
# 5

# %%
s="bananananana"
c=0
for i in s:
  if (i=="n"):
    c=c+1
print(c)
# Out:
# 5

# %%
fruit.find("naa")
# Out:
# -1

# %%
fruit.lower()
# Out:
# 'bananananana'

# %%
fruit.upper()
# Out:
# 'BANANANANANA'

# %%
fruit.capitalize()
# Out:
# 'Bananananana'

# %%
s="hello.World"
print(s.capitalize())
# Out:
# Hello.world

# %%
greet="hello morning"
s1=greet.replace("morning","harshitha")
print(s1)
print(greet)
# Out:
# hello harshitha
# hello morning

# %%
greet="                                      hello morning              "
print(greet.strip())
print(greet)
# Out:
# hello morning
#                                       hello morning

# %%
ls=greet.lstrip()
print(ls)
# Out:
# hello morning

# %%
rs=greet.rstrip()
print(rs)
# Out:
#                                       hello morning

# %%
print("the quality of mercy")
# Out:
# the quality of mercy

# %%
greet=" hello   morning  "
print(greet.split())
# Out:
# ['hello', 'morning']

# %%
a="welcome to gkvk college"
a.split(' ')
# Out:
# ['welcome', 'to', 'gkvk', 'college']

# %%
a.split('')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-636910262.py in <cell line: 0>()
# ----> 1 a.split('')
#
# ValueError: empty separator

# %%
a.split("t")
# Out:
# ['welcome ', 'o gkvk college']

# %%
a.split("E")
# Out:
# ['welcome to gkvk college']

# %%
str1="coffee"
str2=":".join(str1)
print(str1)
print(str2)
# Out:
# coffee
# c:o:f:f:e:e

# %%
str1="coffee"
slen=len(str1)
rev=(str1[slen::-1])
print(rev)
# Out:
# eeffoc

# %%
rev=''.join(reversed(str1))
print(rev)
# Out:
# eeffoc

# %%
a="today is 19-jan-2026 MONDAY"
for i in a:
  if
# Out:
# M
# O
# N
# D
# A
# Y
